# %% [markdown]
# ## We are not epidemiologist or virologist and just we are exploring data

# %%
import pandas as pd

# %%
df = pd.read_excel('data/COVID-19-geographic-disbtribution-worldwide.xlsx', keep_default_na=False, na_values='')

# %%
df.head(5)
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-12-14   14     12  2020    746       6             Afghanistan    AF
# 1 2020-12-13   13     12  2020    298       9             Afghanistan    AF
# 2 2020-12-12   12     12  2020    113      11             Afghanistan    AF
# 3 2020-12-11   11     12  2020     63      10             Afghanistan    AF
# 4 2020-12-10   10     12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# ...

# %% [markdown]
#  Use a count on columns to see how many missing values we have. We would like to analyze countries by geoId.

# %%
df.count()
# Out:
# dateRep                                                       61900
# day                                                           61900
# month                                                         61900
# year                                                          61900
# cases                                                         61900
# deaths                                                        61900
# countriesAndTerritories                                       61900
# geoId                                                         61900
# countryterritoryCode                                          61777
# popData2019                                                   61777
# continentExp                                                  61900
# Cumulative_number_for_14_days_of_COVID-19_cases_per_100000    59021
# dtype: int64

# %%
# No missing values in GeoId
df[df['geoId'].isna()]
# Out:
# Empty DataFrame
# Columns: [dateRep, day, month, year, cases, deaths, countriesAndTerritories, geoId, countryterritoryCode, popData2019, continentExp, Cumulative_number_for_14_days_of_COVID-19_cases_per_100000]
# Index: []

# %%
df_geo = df.dropna(subset=['geoId']).pivot(index='dateRep', columns='geoId', values=['cases', 'deaths'])
df_geo.head(10)
# Out:
#            cases                                          ... deaths           \
# geoId         AD   AE   AF  AG  AI  AL   AM  AO  AR   AT  ...     VG  VI   VN
# dateRep                                                   ...
# 2019-12-31   NaN  0.0  0.0 NaN NaN NaN  0.0 NaN NaN  0.0  ...    NaN NaN  0.0
# 2020-01-01   NaN  0.0  0.0 NaN NaN NaN  0.0 NaN NaN  0.0  ...    NaN NaN  0.0
# 2020-01-02   NaN  0.0  0.0 NaN NaN NaN  0.0 NaN NaN  0.0  ...    NaN NaN  0.0
# 2020-01-03   NaN  0.0  0.0 NaN NaN NaN  0.0 NaN NaN  0.0  ...    NaN NaN  0.0
# 2020-01-04   NaN  0.0  0.0 NaN NaN NaN  0.0 NaN NaN  0.0  ...    NaN NaN  0.0
# 2020-01-05   NaN  0.0  0.0 NaN NaN NaN  0.0 NaN NaN  0.0  ...    NaN NaN  0.0
# 2020-01-06   NaN  0.0  0.0 NaN NaN NaN  0.0 NaN NaN  0.0  ...    NaN NaN  0.0
# 2020-01-07   NaN  0.0  0.0 NaN NaN NaN  0.0 NaN NaN  0.0  ...    NaN NaN  0.0
# 2020-01-08   NaN  0.0  0.0 NaN NaN NaN  0.0 NaN NaN  0.0  ...    NaN NaN  0.0
# ...

# %%
df_geo.describe().transpose()
# Out:
#               count        mean         std   min    25%    50%     75%  \
#        geoId
# cases  AD     276.0   26.586957   49.550669   0.0   0.00    2.0   37.25
#        AE     344.0  537.642442  452.329433   0.0  81.75  451.0  885.75
#        AF     340.0  144.920588  206.561603   0.0   0.00   61.5  200.50
#        AG     270.0    0.548148    2.587412   0.0   0.00    0.0    0.00
#        AI     263.0    0.038023    0.244167   0.0   0.00    0.0    0.00
# ...             ...         ...         ...   ...    ...    ...     ...
# deaths XK     276.0    4.340580    5.600645 -12.0   0.00    2.0    8.00
#        YE     249.0    2.433735    5.432562   0.0   0.00    1.0    3.00
#        ZA     282.0   82.539007   82.997022   0.0  13.25   63.5  118.75
#        ZM     271.0    1.354244    4.240018   0.0   0.00    0.0    1.00
#        ZW     269.0    1.141264    2.614991   0.0   0.00    0.0    1.00
#
#                  max
#        geoId
# cases  AD      299.0
#        AE     1578.0
# ...

# %% [markdown]
# Get to know your data by visualization, in this case the number of new cases per day for my home country BE.

# %%
import matplotlib.pyplot as plt
# case : Belgique
df_geo['cases']['BE'].plot()

# %% [markdown]
# ### Our first idea was to compare the data from france to belgium.

# %%
# case : Belgique + france
(df_geo['cases']['FR'] + df_geo['cases']['BE']).plot()

# %%
# death : Belgique

df_geo['deaths']['BE'].plot()

# %%
# death : Belgique + france

(df_geo['deaths']['BE'] + df_geo['deaths']['FR']).plot()

# %% [markdown]
# ### But, too much difference to be able to use them all at once, we will only be concerned about Belgium.

# %%
df_geo[df_geo['cases']['BE'] > 5000]['cases']['BE']
# Out:
# dateRep
# 2020-10-06     5249.0
# 2020-10-07     5687.0
# 2020-10-08     6803.0
# 2020-10-09     6588.0
# 2020-10-10     7789.0
# 2020-10-13     9735.0
# 2020-10-14    12577.0
# 2020-10-15    12293.0
# 2020-10-16    11818.0
# 2020-10-17    13477.0
# 2020-10-18     7995.0
# 2020-10-20    15560.0
# 2020-10-21    19265.0
# 2020-10-22    17485.0
# 2020-10-23    17687.0
# 2020-10-24    18876.0
# 2020-10-25    11557.0
# 2020-10-27    19868.0
# 2020-10-28    22210.0
# 2020-10-29    17998.0
# 2020-10-30    15090.0
# 2020-10-31    15401.0
# 2020-11-01     6308.0
# 2020-11-03    13858.0
# 2020-11-04    12102.0
# 2020-11-05     9230.0
# 2020-11-06     7659.0
# 2020-11-07     6648.0
# 2020-11-10     8636.0
# 2020-11-11     7701.0
# 2020-11-13     6482.0
# 2020-11-14     5709.0
# 2020-11-17     5821.0
# Name: BE, dtype: float64

# %%
df[(df['geoId'] == 'BE') & (df['dateRep'] == '20201028')]['cases']
# Out:
# 5534    22210
# Name: cases, dtype: int64

# %%
df_geo['cases'][['BE', 'FR']].cumsum().plot()

# %% [markdown]
#  Because of the large difference in numbers, it may help to use a logarithmic scale. We can change the data passed to the plot using the log10 function from NumPy. This will generate some warnings because cases can be zero.

# %%
import numpy as np

df_geo['cases'][['BE', 'FR']].cumsum().plot(logy=True)

# %%
(df_geo.cumsum() / df_geo.shift(1).cumsum(
    ))['cases'][['BE', 'FR']].loc['20200316':].plot()

# %% [markdown]
#  From this factor (relative increase in cases since yesterday) we can calculate the number of days to double the total amount of cases by some logarithmic magic.

# %%
(np.log10(2) / np.log10(df_geo.cumsum() / df_geo.shift().cumsum(
)))['cases'][['BE', 'FR']].loc['20200316':].plot()

# %% [markdown]
# ### Data smoothing

# %% [markdown]
# #### Belgique + france

# %%
df_geo['cases']['FR'].plot() 
df_geo['cases']['BE'].plot()

# %% [markdown]
# Rolling window functions can be used to smooth a curve, in this case the rolling 7 day mean new cases

# %%
df_geo['cases'][['BE', 'FR']].rolling(7).mean().loc['20200101':].plot()

# %% [markdown]
# here with 2 weeks

# %%
df_geo['cases'][['BE', 'FR']].rolling(14, win_type='triang').mean().loc['20200101':].plot()

# %% [markdown]
# #### Belgique only

# %%
df_geo['cases'][['BE']].rolling(7, win_type='triang').mean().loc['20200301':].plot()

# %%
df_geo['cases'][['BE']].rolling(14).sum().plot()

# %%
df_geo['cases']['BE'].rolling(14, win_type='triang').mean().plot()

# %% [markdown]
# ### Difference between waves

# %%
df_geo[[('cases', 'BE'), ('deaths', 'BE')]].rolling(14, win_type='triang').mean().loc['20200101':'20200701'].plot() 
df_geo[[('cases', 'BE'), ('deaths', 'BE')]].rolling(14, win_type='triang').mean().loc['20200901':].plot()

# %% [markdown]
# With logarithmic values :

# %%
df_geo[[('cases', 'BE'), ('deaths', 'BE')]].rolling(14, win_type='triang').mean().loc['20200101':'20200701'].plot(logy=True) 
df_geo[[('cases', 'BE'), ('deaths', 'BE')]].rolling(14, win_type='triang').mean().loc['20200901':].plot(logy=True)

# %% [markdown]
# ### Infection rates

# %%
countries = ['BE']

(df_geo.rolling(7).mean() / df_geo.shift(7).rolling(14).mean(
    )).rolling(7).mean()['cases'][countries].loc['20200301':].plot(
    figsize=(16, 9), grid=True, ylim=(0, 3))

# %% [markdown]
# #### An estimate of the death rate for known cases

# %%
(df_geo.rolling(7).mean()['deaths'] / df_geo.shift(7).rolling(14).mean(
    ).rolling(7).mean()['cases'])[countries].loc['20200401':].plot(
    figsize=(16, 9), grid=True)

# %%
# total death by case
(df_geo.rolling(7).mean()['deaths'] / df_geo.shift(7).rolling(14).mean(
    )['cases'])[countries].loc['20200401':].mean()
# Out:
# geoId
# BE    0.054059
# dtype: float64

# %%
# death by case from the first waves

(df_geo.rolling(7).mean()['deaths'] / df_geo.shift(7).rolling(14).mean(
    )['cases'])[countries].loc['20200101':'20200701'].mean()
# Out:
# geoId
# BE    0.116378
# dtype: float64

# %%
# death by case from the second waves

(df_geo.rolling(7).mean()['deaths'] / df_geo.shift(7).rolling(14).mean(
    )['cases'])[countries].loc['20201001':].mean()
# Out:
# geoId
# BE    0.018221
# dtype: float64

# %% [markdown]
# ### Trying to fit a thing

# %% [markdown]
# Most algorithms take numerical data as inputs for a model, so we add a column representing the date as days since January 1st, 2019. To access the date values in the index easily, we first create a separate column.

# %%
df_geo['daynum'] = (df_geo.index - df_geo.index.min()).days
df_geo['daynum'].describe()
# Out:
# count    350.000000
# mean     174.500000
# std      101.180532
# min        0.000000
# 25%       87.250000
# 50%      174.500000
# 75%      261.750000
# max      349.000000
# Name: daynum, dtype: float64

# %% [markdown]
# #### First wave

# %%
country  = 'BE'
measure  = 'cases'
pmeasure = 'pcases'

df_pred = pd.DataFrame({'x':df_geo['daynum'], 'y':df_geo[measure][country].loc[:'20200501'].rolling(7).mean()})
df_pred = df_pred[df_pred['y'] > 100]
df_pred['y'] = np.log10(df_pred['y'])
df_pred['y'].plot()

# %%
df_pred['g'] = np.gradient(df_pred['y'])
df_pred['g'].plot()

# %%
fit = np.polyfit(x=df_pred['x'], y=df_pred['g'], deg=1, full=True)
print(country, "factors", fit[0], "residuals", fit[1][0])

df_pred['r'] = np.polyval(fit[0], df_pred['x'])
df_pred[['g', 'r']].plot()
# Out:
# BE factors [-0.00261634  0.26915091] residuals 0.012990143861071939

# %%
# We are using 4 degre for the training for better prediction
fit = np.polyfit(x=df_pred['x'], y=df_pred['y'], deg=4, full=True)
print(country, "factors", fit[0], "residuals", fit[1][0])

df_pred['p'] = np.polyval(fit[0], df_pred['x'])
df_pred[['y', 'p']].plot()
# Out:
# BE factors [-1.64761619e-07  7.59524096e-05 -1.40102668e-02  1.18412513e+00
#  -3.46020527e+01] residuals 0.03030626416720602

# %%
df_geo[(pmeasure, country)] = 10 ** np.polyval(fit[0], df_geo['daynum'])
df_geo[[(measure, country), (pmeasure, country)]].plot(figsize=(16, 9), grid=True)
plotlist = [(pmeasure, country)]

# %%
df_geo[[(measure, country), (pmeasure, country)]].cumsum().plot(figsize=(16, 9), grid=True)

# %% [markdown]
# #### Second Waves

# %%
country  = 'BE'
measure  = 'cases'
pmeasure = 'pcases'

df_pred = pd.DataFrame({'x':df_geo['daynum'], 'y':df_geo[measure][country].loc['20200901':'20201201'].rolling(14).mean()})
df_pred = df_pred[df_pred['y'] > 100]
df_pred['y'] = np.log10(df_pred['y'])
df_pred['y'].plot()

# %%
df_pred['g'] = np.gradient(df_pred['y'])
df_pred['g'].plot()

# %%
fit = np.polyfit(x=df_pred['x'], y=df_pred['g'], deg=1, full=True)
print(country, "factors", fit[0], "residuals", fit[1][0])

df_pred['r'] = np.polyval(fit[0], df_pred['x'])
df_pred[['g', 'r']].plot()
# Out:
# BE factors [-0.0010026   0.30501234] residuals 0.02629000607289812

# %%
# We are using 4 degre for the training for better prediction
fit = np.polyfit(x=df_pred['x'], y=df_pred['y'], deg=8, full=True)
print(country, "factors", fit[0], "residuals", fit[1][0])

df_pred['p'] = np.polyval(fit[0], df_pred['x'])
df_pred[['y', 'p']].plot()
# Out:
# BE factors [-2.98417279e-14  6.57127887e-11 -6.31818798e-08  3.46715814e-05
#  -1.18887633e-02  2.61156695e+00 -3.59402680e+02  2.83764775e+04
#  -9.85846078e+05] residuals 0.012446242649757373

# %%
df_geo[(pmeasure, country)] = 10 ** np.polyval(fit[0], df_geo['daynum'])
df_geo[[(measure, country), (pmeasure, country)]].plot(figsize=(16, 9), grid=True)
plotlist = plotlist + [(pmeasure, country)]

# %%
df_geo[[(measure, country), (pmeasure, country)]].cumsum().plot(figsize=(16, 9), grid=True)

# %%
df_geo[plotlist].loc['20200301':'20210301'].plot(
            figsize=(16, 9),
            grid=True,
            kind='area',
            stacked=False,
            alpha=1/3,
            title='Daily new cases for ')
